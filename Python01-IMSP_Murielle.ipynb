# %% [markdown]
# 1/
#
# i)
# nombre=int(input("Entrez un nombre : "))
#
# i=s=0
#
# while(i< nombre):
#     if(i%2):
#         s+=i+3
#     i=i+1
# print(s)
#
#
# ii)
#
# nombre=int(input("Entrez un nombre : "))
#
# i,s=0,1
#
# while(i< nombre):
#     if(i%2==0):
#         s*=i+3
#     i=i+1
# print(s)
#
# 2/
#
# day=list(['lundi', 'mardi', 'mercredi', 'jeudi','vendredi','Weekend'])
# nombre=int(input("Entrez un nombre : "))
# print(day)
# if(nombre<0 and nombre>=7):
#     i=0
#     print(i)
# while(i==0):
#   nombre=int(input("Entrez un nombre : "))
#   if(nombre<0 and nombre>=7):
#     i=0
#   else:
#     i=1
#
#
# if(nombre<5):
#     print('Today we are',day[nombre])
# else:
#     print(day[nombre])
#
#
# 3/
# month=[31,28,31,30,31,30,31,31,30,31,30,31]
# j=0
# nombre=int(input("Entrez un nombre : "))
# print(month)
# if(nombre<0 and nombre>=12):
#     i=0
#     print(i)
# while(i==0):
#   nombre=int(input("Entrez un nombre : "))
#   if(nombre<0 and nombre>=12):
#     i=0
#   else:
#     i=1
#
# print('in the month ', nombre+1, 'there is', month[nombre], 'days' )
#
#
#
# 4/
#
# for i in range(3):
#     print('Murielle AGBAHOLOU')
#
# i=1
# while i < 4 :
#     print('Murielle AGBAHOLOU')
#     i=i+1
#
# 5/
# nombre0=int(input("Entrez un nombre : "))
# nombre1=int(input("Entrez un nombre : "))
# tab= [nombre0,nombre1]
# print(tab)
# i=2
# while(i<15):
#     tab.append( tab[i-1]+tab[i-2])
#     i=i+1
# print (tab)
#
# 6/
# nombre0=int(input("Entrez un nombre : "))
# nombre1=int(input("Entrez un nombre : "))
# tab= [nombre0,nombre1]
# print(tab)
# i=2
# while(i<30):
#     tab.append( (0.5*tab[i-1])+(3*tab[i-2]))
#     i=i+1
# print (tab)
#
#
# 10/
#
# n=int(input("Entrez un nombre entre 0 et 9: "))
# N=int(input("Entrez un nombre : "))
# i=4
#
# print(i)
# if( n < 0 and n >= 10):
#     i=0
#     print(i)
# while(i==0):
#   n = int(input("Entrez un nombre entre 0 et 9: "))
#   if(n<0 and n>=10):
#     i=0
#   else:
#     i=1
#
# if( N<0 ):
#     i=0
#     print(i)
# while(i==0):
#   N=int(input("Entrez un nombre supérieur à 0: "))
#   if( N<0 ):
#     i=0
#   else:
#     i=1
#
# print('table de multiplication')
#
# i=0
#
# while i <=N :
#     print(n,'*',i,'=',n*i)
#     i=i+1
#
#
#
#
#
# 11/
#
#
# print('Multiple de 3:\n')
# i=0
# while( i <= 40):
#     if( i%3 == 0)
#     print (i,'\n')
#     i=i+1
#
#
# print('Multiple de 7:\n')
# i=0
# while( i <= 40):
#     if( i%7 == 0)
#     print (i,'\n')
#     i=i+1
#
# print('Multiple de 11:\n')
# i=0
# while( i <= 40):
#     if( i%11 == 0)
#     print (i,'\n')
#     i=i+1

# %%
print('Multiple de 3:\n')
i=0
while( i <= 40):
    if( i%3 == 0)
    print (i,'\n')
    i=i+1
# Out:
#   File "<ipython-input-5-2d7c624754cd>", line 4
#     if( i%3==0)
#                ^
# SyntaxError: invalid syntax
