# %% [markdown]
# 1/
#
# i)
# nombre=int(input("Entrez un nombre : "))
#
# i=s=0
#
# while(i< nombre):
#     if(i%2):
#         s+=i+3
#     i=i+1
# print(s)
#
#
# ii)
#
# nombre=int(input("Entrez un nombre : "))
#
# i,s=0,1
#
# while(i< nombre):
#     if(i%2==0):
#         s*=i+3
#     i=i+1
# print(s)
#
# 2/
#
# day=list(['lundi', 'mardi', 'mercredi', 'jeudi','vendredi','Weekend'])
# nombre=int(input("Entrez un nombre : "))
# print(day)
# if(nombre<0 and nombre>=7):
#     i=0
#     print(i)
# while(i==0):
#   nombre=int(input("Entrez un nombre : "))
#   if(nombre<0 and nombre>=7):
#     i=0
#   else:
#     i=1
#
#
# if(nombre<5):
#     print('Today we are',day[nombre])
# else:
#     print(day[nombre])
#
#
# 3/
# month=[31,28,31,30,31,30,31,31,30,31,30,31]
# j=0
# nombre=int(input("Entrez un nombre : "))
# print(month)
# if(nombre<0 and nombre>=12):
#     i=0
#     print(i)
# while(i==0):
#   nombre=int(input("Entrez un nombre : "))
#   if(nombre<0 and nombre>=12):
#     i=0
#   else:
#     i=1
#
# print('in the month ', nombre+1, 'there is', month[nombre], 'days' )
#
#
#
# 4/
#
# for i in range(3):
#     print('Murielle AGBAHOLOU')
#
# i=1
# while i < 4 :
#     print('Murielle AGBAHOLOU')
#     i=i+1
#
# 5/
# nombre0=int(input("Entrez un nombre : "))
# nombre1=int(input("Entrez un nombre : "))
# tab= [nombre0,nombre1]
# print(tab)
# i=2
# while(i<15):
#     tab.append( tab[i-1]+tab[i-2])
#     i=i+1
# print (tab)
#
# 6/
# nombre0=int(input("Entrez un nombre : "))
# nombre1=int(input("Entrez un nombre : "))
# tab= [nombre0,nombre1]
# print(tab)
# i=2
# while(i<30):
#     tab.append( (0.5*tab[i-1])+(3*tab[i-2]))
#     i=i+1
# print (tab)
# 7/

# %%
# Out:
# Entrez un nombre : 5
# Entrez un nombre : 4
# [5, 4]
# [5, 4, 17.0, 20.5, 61.25, 92.125, 229.8125, 391.28125, 885.078125, 1616.3828125, 3463.42578125, 6580.861328125, 13680.7080078125, 26582.93798828125, 54333.593017578125, 106915.61047363281, 216458.58428955078, 428976.1235656738, 863863.8146514893, 1718860.278022766, 3451021.582965851, 6882091.625551224, 13794110.561673164, 27543330.157490253, 55153996.76376462, 110206988.85435307, 220565484.7184704, 440903708.9222944, 882148308.6165584, 1763785281.0751624]
