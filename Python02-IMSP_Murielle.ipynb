# %%
1/

from math import sin, sqrt
x = int(input('Entrez un nombre x: '))

y = int(input('Entrez un nombre y: '))

print(sqrt(x**(2+y))/((1/x)+(2*sin(y))))


2/
---For n positive

def ownpowerfn(b,n):
    i=1
    pow=1
    if (n==0):
        return 1
    else:
       while(i <= n):
           pow*=b
           i=i+1
       return pow




b = int(input('Entrez un nombre b: '))

n = int(input('Entrez un nombre n: '))

if(n<0 ): 
     i=0 
while(i==0):
     n=int(input("Entrez un nombre n positif : "))
if(n<0 ):
    i=0 
else:
    i=1

print(ownpowerfn(b,n))


---If n's nature is not specified


def ownpowerfn(b,n):
    i=1
    pow=1
    if (n==0):
        return 1
    elif(n>1):
        while(i <= n):
           pow *=b
           i=i+1
        return pow
    else:
        while(i <= -n):
            
            pow *=(1/b)
            i=i+1
        return pow  



b = int(input('Entrez un nombre b: '))

n = int(input('Entrez un nombre n: '))



print(ownpowerfn(b,n))


3/
a-

from math import sqrt
def  arithmetic_mean(x,y):
    return (x+y)/2


def geometric_mean(x,y):
    return (sqrt(x*y))



b-


def fahrenheit_to_celcius(deg):
    return (deg-32)/1.8
    

def celcius_to_fahrenheit(deg):
    return (deg+32)/(5/9)

c-
from math import pi
def degrees_to_radians(deg):
    return deg*(pi/180) 

def radians_to_degrees(deg):
    if((deg%(1/pi)==0)):
        return 180/(deg/(1/pi))
    else:
        return (deg*(180/pi))
    

d-

from math import pi
def area (r):
        return r**2*pi
    
def circumference(r):
        return 2*r*pi

    
    
4/
a-





b-
    return (sqrt(x*y))

from math import sqrt
def  arithmetic_mean(x,y):
    print('arithmetic average: ', arithmetic_mean(x,y))
    return (x+y)/2


def geometric_mean(x,y):
    print('geometric average: ',geometric_mean(x,y))
    return (sqrt(x*y))




def avggeom(x,y):
    i=1
    x=arithmetic_mean(x,y)
    y=geometric_mean(x,y)
    for i in range(1,11):
        return def avggeom(x,y)
    
        
x = int(input('Entrez un nombre x: '))

y = int(input('Entrez un nombre y: '))

if(x<0 and y>=0): 
     i=0 
while(i==0):
    print('entrez deux nombres positifs ou deux nombres negatifs')
    x = int(input('Entrez un nombre x: '))

    y = int(input('Entrez un nombre y: '))
if( (x<0 and y>0)) or (x>0 and y<0)) : 
    i=0 
else:
    i=1

b-









7-

# %%
def Fibonacci:
    
    if
